# %% [markdown]
# <a href="https://colab.research.google.com/github/viratchowdary21/Hakuna-Matata-Hire-a-thon-Freshers_Virat/blob/main/Employee_performance_problem_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import statistics as st

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/Copy of Hackathon Timesheet.xlsx'

# %%
scrum_sheet = pd.read_excel('/content/drive/MyDrive/Copy of Hackathon Timesheet.xlsx')

# %%
np.all([1,2,3,4,5,5])
# Out:
# True

# %%
scrum_sheet.head()
# Out:
#          Date Project Name  Hours   Owner    Team Billing Status
# 0  23-02-2015         AAA     1.5  sankar  Design       Billable
# 1  18-02-2015         AAA     1.5  sankar  Design       Billable
# 2  16-02-2015         AAA     3.0  sankar  Design       Billable
# 3  13-02-2015         AAA     1.5  sankar  Design       Billable
# 4  12-02-2015         AAA     6.5  sankar  Design       Billable

# %%
scrum_sheet['Project Name'].nunique()
# Out:
# 55

# %%
scrum_sheet['Billing Status'] = scrum_sheet['Billing Status'].apply(lambda x: 1 if x=='Billable' else 0)

# %%
noof_projects = pd.pivot_table(scrum_sheet, values=['Project Name'],
                                 index=['Team', 'Date'], columns=None,
                   aggfunc= lambda x: len(x.unique()),
                    margins = True, margins_name='Totals', sort=True)

noof_projects
# Out:
#                    Project Name
# Team   Date
# 0      05-08-2014             1
# Design 01-04-2014             3
#        01-05-2014             2
#        01-06-2014             1
#        01-07-2014             5
# ...                         ...
# QA     31-01-2015             2
#        31-07-2014             2
#        31-10-2014             3
#        31-12-2014             2
# Totals                       55
#
# [1039 rows x 1 columns]

# %%
emp_performance = pd.pivot_table(scrum_sheet, values=['Hours', 'Billing Status', 'Project Name'],
                                 index=['Team', 'Owner', 'Date'], columns=None, 
                   aggfunc={'Hours':np.sum, 'Billing Status':np.modf, 'Project Name': lambda x: len(x.unique())},
                    margins = True, margins_name='Totals', sort=True)
emp_performance
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1061         try:
# -> 1062             self._set_with_engine(key, value)
#    1063         except (KeyError, ValueError):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#    1098         validate_numeric_casting(self.dtype, value)  # type: ignore[arg-type]
# -> 1099         self._values[loc] = value
#    1100
#
# ValueError: setting an array element with a sequence.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
emp_performance[emp_performance['Project Name']>7]
# Out:
#                                         Billing Status     Hours  Project Name
# Team   Owner                Date
# PM     ithayakumar Durairaj 29-01-2015        1.000000      7.50             9
# Totals                                        0.919772  37439.38            55

# %%
emp_performance = pd.merge(emp_performance, noof_projects, 'left', left_index=True, right_index=True)
emp_performance
# Out:
#                                       Billing Status     Hours  \
# Team   Date       Owner
# 0      05-08-2014 0                         1.000000      0.50
# Design 01-04-2014 Murali                    1.000000      0.75
#                   Vignesh Ramamurthy        1.000000     10.75
#                   sankar                    1.000000      8.67
#        01-05-2014 Vignesh Ramamurthy        1.000000      9.83
# ...                                              ...       ...
# QA     31-10-2014 Solomon Gracious          1.000000      8.00
#                   nixon                     1.000000      7.50
#        31-12-2014 Solomon Gracious          1.000000      4.00
#                   nixon                     1.000000      8.00
# Totals                                      0.919772  37439.38
#
#                                       Project Name_x  Project Name_y
# Team   Date       Owner
# 0      05-08-2014 0                                1               1
# ...

# %%
emp_performance = emp_performance.reset_index()
emp_performance
# Out:
#         Team        Date               Owner  Billing Status     Hours  \
# 0          0  05-08-2014                   0        1.000000      0.50
# 1     Design  01-04-2014              Murali        1.000000      0.75
# 2     Design  01-04-2014  Vignesh Ramamurthy        1.000000     10.75
# 3     Design  01-04-2014              sankar        1.000000      8.67
# 4     Design  01-05-2014  Vignesh Ramamurthy        1.000000      9.83
# ...      ...         ...                 ...             ...       ...
# 5300      QA  31-10-2014    Solomon Gracious        1.000000      8.00
# 5301      QA  31-10-2014               nixon        1.000000      7.50
# 5302      QA  31-12-2014    Solomon Gracious        1.000000      4.00
# 5303      QA  31-12-2014               nixon        1.000000      8.00
# 5304  Totals                                        0.919772  37439.38
#
#       Project Name_x  Project Name_y
# 0                  1               1
# 1                  1               3
# ...

# %%
emp_performance
# Out:
#         Team        Date               Owner  Billing Status     Hours  \
# 0          0  05-08-2014                   0        1.000000      0.50
# 1     Design  01-04-2014              Murali        1.000000      0.75
# 2     Design  01-04-2014  Vignesh Ramamurthy        1.000000     10.75
# 3     Design  01-04-2014              sankar        1.000000      8.67
# 4     Design  01-05-2014  Vignesh Ramamurthy        1.000000      9.83
# ...      ...         ...                 ...             ...       ...
# 5300      QA  31-10-2014    Solomon Gracious        1.000000      8.00
# 5301      QA  31-10-2014               nixon        1.000000      7.50
# 5302      QA  31-12-2014    Solomon Gracious        1.000000      4.00
# 5303      QA  31-12-2014               nixon        1.000000      8.00
# 5304  Totals                                        0.919772  37439.38
#
#       Project Name_x  Project Name_y
# 0                  1               1
# 1                  1               3
# ...

# %%
emp_performance = pd.pivot_table(emp_performance, values=['Hours', 'Billing Status', 'Project Name_x', 'Project Name_y'],
                                 index=['Team', 'Owner', 'Date'], columns=None, 
                  #  aggfunc={'Hours':np.sum, 'Billing Status':np.mean, 'Project Name': lambda x: len(x.unique())},
                    # margins = True, margins_name='Totals', 
                    sort=True)
emp_performance
# Out:
#                              Billing Status     Hours  Project Name_x  \
# Team   Owner     Date
# 0      0         05-08-2014        1.000000      0.50               1
# Design Murali    01-04-2014        1.000000      0.75               1
#                  01-07-2014        1.000000      8.00               2
#                  01-08-2014        1.000000      7.00               1
#                  01-09-2014        1.000000      3.00               1
# ...                                     ...       ...             ...
# QA     yuvaraj s 21-05-2014        0.000000     10.00               1
#                  23-02-2015        0.200000     15.00               1
#                  23-04-2014        1.000000      1.00               1
#                  24-02-2015        0.000000      1.50               1
# Totals                             0.919772  37439.38              55
#
#                              Project Name_y
# Team   Owner     Date
# ...

# %%
emp_performance['effeciency'] = (emp_performance['Billing Status']+1)*emp_performance['Hours']*\
(emp_performance['Project Name_x']/emp_performance['Project Name_y'])
emp_performance
# Out:
#                                       Billing Status     Hours  \
# Team   Date       Owner
# 0      05-08-2014 0                         1.000000      0.50
# Design 01-04-2014 Murali                    1.000000      0.75
#                   Vignesh Ramamurthy        1.000000     10.75
#                   sankar                    1.000000      8.67
#        01-05-2014 Vignesh Ramamurthy        1.000000      9.83
# ...                                              ...       ...
# QA     31-10-2014 Solomon Gracious          1.000000      8.00
#                   nixon                     1.000000      7.50
#        31-12-2014 Solomon Gracious          1.000000      4.00
#                   nixon                     1.000000      8.00
# Totals                                      0.919772  37439.38
#
#                                       Project Name_x  Project Name_y  \
# Team   Date       Owner
# 0      05-08-2014 0                                1               1
# ...

# %%
emp_performance = emp_performance.sort_values(['Owner', 'effeciency'], ascending=False).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-4d23afcf5ca5> in <module>
# ----> 1 emp_performance = emp_performance.sort_values(['Owner', 'effeciency'], ascending=False).reset_index()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6240         if len(by) > 1:
#    6241
# -> 6242             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6243
#    6244             # need to rewrap columns in Series to apply key function
#
# ...

# %%
# emp_performance['mean_effeciency'] = emp_performance.effeciency.groupby(level=['Team', 'Owner']).sum()

# %%
emp_performance
# Out:
#                                  Billing Status     Hours  Project Name_x  \
# Team   Date       Owner
# QA     09-02-2015 yuvaraj s            0.400000     38.50               1
#        11-02-2015 yuvaraj s            1.000000     15.08               1
#        23-02-2015 yuvaraj s            0.200000     15.00               1
#        21-05-2014 yuvaraj s            0.000000     10.00               1
#        21-04-2014 yuvaraj s            0.000000      5.00               1
# ...                                         ...       ...             ...
# PM     10-05-2014 Akhila Kannan        1.000000      1.00               1
#        20-05-2014 Akhila Kannan        1.000000      1.50               1
#        06-09-2014 Akhila Kannan        1.000000      0.50               1
# 0      05-08-2014 0                    1.000000      0.50               1
# Totals                                 0.919772  37439.38              55
#
# ...

# %%
emp_performance_df = emp_performance.reset_index().sort_values('mean_effeciency', ascending=True).drop(['Date'], axis=1)

# %%
emp_performance_df.Owner[emp_performance_df['mean_effeciency']<70].unique()
# Out:
# array([], dtype=object)
